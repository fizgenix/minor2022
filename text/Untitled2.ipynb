# %%
pip install -r requirements.txt
# Out:
# Collecting textract==1.6.3
#   Using cached textract-1.6.3-py3-none-any.whl (21 kB)
# Collecting requests==2.22.0
#   Using cached requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Collecting Flask==1.1.1
#   Using cached Flask-1.1.1-py2.py3-none-any.whl (94 kB)
# Collecting gensim==3.8.0
#   Using cached gensim-3.8.0.tar.gz (23.4 MB)
#   Preparing metadata (setup.py) ... done
# Collecting sklearn==0.0
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting PyPDF2==1.26.0
#   Using cached PyPDF2-1.26.0.tar.gz (77 kB)
#   Preparing metadata (setup.py) ... done
# Collecting autocorrect==0.4.4
#   Using cached autocorrect-0.4.4.tar.gz (19.1 MB)
#   Preparing metadata (setup.py) ... done
# Collecting nltk==3.4.5
#   Using cached nltk-3.4.5.zip (1.5 MB)
#   Preparing metadata (setup.py) ... done
# Collecting contractions==0.0.21
#   Using cached contractions-0.0.21-py2.py3-none-any.whl (2.9 kB)
# Collecting textsearch==0.0.17
#   Using cached textsearch-0.0.17-py2.py3-none-any.whl (7.5 kB)
# Collecting inflect==2.1.0
#   Using cached inflect-2.1.0-py2.py3-none-any.whl (40 kB)
# Collecting numpy==1.17.2
#   Using cached numpy-1.17.2.zip (6.5 MB)
#   Preparing metadata (setup.py) ... done
# Collecting pdfminer.six==20181108
#   Using cached pdfminer.six-20181108-py2.py3-none-any.whl (5.6 MB)
# Collecting EbookLib==0.17.1
#   Using cached EbookLib-0.17.1.tar.gz (111 kB)
#   Preparing metadata (setup.py) ... done
# Collecting beautifulsoup4==4.8.0
#   Using cached beautifulsoup4-4.8.0-py3-none-any.whl (97 kB)
# Requirement already satisfied: SpeechRecognition==3.8.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract==1.6.3->-r requirements.txt (line 1)) (3.8.1)
# Collecting argcomplete==1.10.0
#   Using cached argcomplete-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: docx2txt==0.8 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract==1.6.3->-r requirements.txt (line 1)) (0.8)
# Requirement already satisfied: xlrd==1.2.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract==1.6.3->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: chardet==3.0.4 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract==1.6.3->-r requirements.txt (line 1)) (3.0.4)
# Collecting python-pptx==0.6.18
#   Using cached python-pptx-0.6.18.tar.gz (8.9 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six==1.12.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract==1.6.3->-r requirements.txt (line 1)) (1.12.0)
# Collecting extract-msg==0.23.1
#   Using cached extract_msg-0.23.1-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from requests==2.22.0->-r requirements.txt (line 2)) (2022.9.24)
# Collecting idna<2.9,>=2.5
#   Using cached idna-2.8-py2.py3-none-any.whl (58 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask==1.1.1->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask==1.1.1->-r requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask==1.1.1->-r requirements.txt (line 3)) (2.0.3)
# Requirement already satisfied: click>=5.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask==1.1.1->-r requirements.txt (line 3)) (8.0.4)
# Requirement already satisfied: scipy>=0.18.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim==3.8.0->-r requirements.txt (line 4)) (1.9.1)
# Requirement already satisfied: smart_open>=1.7.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim==3.8.0->-r requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: scikit-learn in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from sklearn==0.0->-r requirements.txt (line 5)) (1.0.2)
# Collecting pyahocorasick
#   Using cached pyahocorasick-1.4.4-cp39-cp39-macosx_10_9_x86_64.whl (32 kB)
# Requirement already satisfied: Unidecode in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textsearch==0.0.17->-r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: pycryptodome in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six==20181108->-r requirements.txt (line 13)) (3.15.0)
# Requirement already satisfied: sortedcontainers in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six==20181108->-r requirements.txt (line 13)) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4==4.8.0->textract==1.6.3->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: lxml in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from EbookLib==0.17.1->textract==1.6.3->-r requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: imapclient==2.1.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from extract-msg==0.23.1->textract==1.6.3->-r requirements.txt (line 1)) (2.1.0)
# Collecting tzlocal==1.5.1
#   Using cached tzlocal-1.5.1.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: olefile==0.46 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from extract-msg==0.23.1->textract==1.6.3->-r requirements.txt (line 1)) (0.46)
# Requirement already satisfied: Pillow>=3.3.2 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from python-pptx==0.6.18->textract==1.6.3->-r requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from python-pptx==0.6.18->textract==1.6.3->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: pytz in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from tzlocal==1.5.1->extract-msg==0.23.1->textract==1.6.3->-r requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask==1.1.1->-r requirements.txt (line 3)) (2.0.1)
# Collecting scipy>=0.18.1
#   Using cached scipy-1.9.3-cp39-cp39-macosx_10_9_x86_64.whl (34.3 MB)
#   Using cached scipy-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl (34.3 MB)
#   Using cached scipy-1.9.0-cp39-cp39-macosx_12_0_universal2.macosx_10_9_x86_64.whl (58.4 MB)
#   Using cached scipy-1.8.1-cp39-cp39-macosx_12_0_universal2.macosx_10_9_x86_64.whl (55.6 MB)
#   Using cached scipy-1.8.0-cp39-cp39-macosx_12_0_universal2.macosx_10_9_x86_64.whl (55.6 MB)
#   Using cached scipy-1.7.3-cp39-cp39-macosx_10_9_x86_64.whl (33.2 MB)
# Requirement already satisfied: joblib>=0.11 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn==0.0->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn==0.0->-r requirements.txt (line 5)) (2.2.0)
# Building wheels for collected packages: gensim, sklearn, PyPDF2, autocorrect, nltk, numpy, EbookLib, python-pptx, tzlocal
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.8.0-cp39-cp39-macosx_10_9_x86_64.whl size=23909646 sha256=d84d8e5f2e700f8c67ec2c73ff3e52e546d666715700b8e64a559ddb1dc15a21
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/fb/18/fa/2a0084905c1be0cead09a515d05015c1f939afb16fd7893ff4
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=a0141d5e6919fdfd9c5082fbe5df38f6539a9b7302b4ffb00bbbca8ee017ecc1
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61082 sha256=9607876643c797ffd8f91e3c148eb3b7c58766f4e99c30eac4a778f2d6f16bae
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/d9/dc/ec/72da68331f30074b9950c1737c23cb8a67484e61498bc9713d
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-0.4.4-py3-none-any.whl size=19134797 sha256=27f1a0ac9bdbe5a9157331d85f17cc55fcb390c9437b526e76b969b0391c5673
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/2d/80/a5/4215b9c72b4d12687c3e67c124cb369069d45640b57e4918b5
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4.5-py3-none-any.whl size=1449908 sha256=5f6b3be0b27b5f9774a837dbf92d0e3794ce9b4b0bee677cce878209d9ec8857
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/04/32/57/69e42ad50941013def31e288c6e06bb569442dd993a123cb76
#   Building wheel for numpy (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2297 lines of output]
#       Running from numpy source directory.
#       blas_opt_info:
#       blas_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#       /bin/sh: svnversion: command not found
#       non-existing path in 'numpy/distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#       non-existing path in 'numpy/random': 'src/splitmix64/splitmix.h'
#       /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:262: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       creating build
#       creating build/src.macosx-10.9-x86_64-3.9
#       creating build/src.macosx-10.9-x86_64-3.9/numpy
#       creating build/src.macosx-10.9-x86_64-3.9/numpy/distutils
#       building library "npymath" sources
#       get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize NAGFCompiler
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       Could not locate executable f77
#       customize IBMFCompiler
#       Could not locate executable xlf90
#       Could not locate executable xlf
#       customize IntelFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifc
#       customize GnuFCompiler
#       Could not locate executable g77
#       customize G95FCompiler
#       Could not locate executable g95
#       customize PGroupFCompiler
#       Could not locate executable pgfortran
#       don't know how to compile Fortran code on platform 'posix'
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       clang _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       _configtest.c:1:5: warning: incompatible redeclaration of library function 'exp' [-Wincompatible-library-redeclaration]
#       int exp (void);
#           ^
#       _configtest.c:1:5: note: 'exp' is a builtin with type 'double (double)'
#       1 warning generated.
#       clang _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       creating build/src.macosx-10.9-x86_64-3.9/numpy/core
#       creating build/src.macosx-10.9-x86_64-3.9/numpy/core/src
#       creating build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/npy_math_internal.h
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath' to include_dirs.
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/ieee754.c
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/npy_math_complex.c
#       None - nothing done with h_files = ['build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/npy_math_internal.h']
#       building library "npysort" sources
#       creating build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_sort.h
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common' to include_dirs.
#       creating build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort/quicksort.c
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort/mergesort.c
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort/timsort.c
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort/heapsort.c
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort/radixsort.c
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_partition.h
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort/selection.c
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_binsearch.h
#       conv_template:> build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npysort/binsearch.c
#       None - nothing done with h_files = ['build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_sort.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_partition.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_binsearch.h']
#       building extension "numpy.core._dummy" sources
#       Generating build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/config.h
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       _configtest.c:1:10: fatal error: 'endian.h' file not found
#       #include <endian.h>
#                ^~~~~~~~~~
#       1 error generated.
#       failure.
#       removing: _configtest.c _configtest.o
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       _configtest.c:1:10: fatal error: 'sys/endian.h' file not found
#       #include <sys/endian.h>
#                ^~~~~~~~~~~~~~
#       1 error generated.
#       failure.
#       removing: _configtest.c _configtest.o
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       _configtest.c:7:12: error: use of undeclared identifier 'SIZEOF_LONGDOUBLE'
#           (void) SIZEOF_LONGDOUBLE;
#                  ^
#       1 error generated.
#       failure.
#       removing: _configtest.c _configtest.o
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       _configtest.c:1:5: warning: incompatible redeclaration of library function 'exp' [-Wincompatible-library-redeclaration]
#       int exp (void);
#           ^
#       _configtest.c:1:5: note: 'exp' is a builtin with type 'double (double)'
#       1 warning generated.
#       clang _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       _configtest.c:1:5: warning: incompatible redeclaration of library function 'sin' [-Wincompatible-library-redeclaration]
#       int sin (void);
#           ^
#       _configtest.c:1:5: note: 'sin' is a builtin with type 'double (double)'
#       _configtest.c:2:5: warning: incompatible redeclaration of library function 'cos' [-Wincompatible-library-redeclaration]
#       int cos (void);
#           ^
#       _configtest.c:2:5: note: 'cos' is a builtin with type 'double (double)'
#       _configtest.c:3:5: warning: incompatible redeclaration of library function 'tan' [-Wincompatible-library-redeclaration]
#       int tan (void);
#           ^
#       _configtest.c:3:5: note: 'tan' is a builtin with type 'double (double)'
#       _configtest.c:4:5: warning: incompatible redeclaration of library function 'sinh' [-Wincompatible-library-redeclaration]
#       int sinh (void);
#           ^
#       _configtest.c:4:5: note: 'sinh' is a builtin with type 'double (double)'
#       _configtest.c:5:5: warning: incompatible redeclaration of library function 'cosh' [-Wincompatible-library-redeclaration]
#       int cosh (void);
#           ^
#       _configtest.c:5:5: note: 'cosh' is a builtin with type 'double (double)'
#       _configtest.c:6:5: warning: incompatible redeclaration of library function 'tanh' [-Wincompatible-library-redeclaration]
#       int tanh (void);
#           ^
#       _configtest.c:6:5: note: 'tanh' is a builtin with type 'double (double)'
#       _configtest.c:7:5: warning: incompatible redeclaration of library function 'fabs' [-Wincompatible-library-redeclaration]
#       int fabs (void);
#           ^
#       _configtest.c:7:5: note: 'fabs' is a builtin with type 'double (double)'
#       _configtest.c:8:5: warning: incompatible redeclaration of library function 'floor' [-Wincompatible-library-redeclaration]
#       int floor (void);
#           ^
#       _configtest.c:8:5: note: 'floor' is a builtin with type 'double (double)'
#       _configtest.c:9:5: warning: incompatible redeclaration of library function 'ceil' [-Wincompatible-library-redeclaration]
#       int ceil (void);
#           ^
#       _configtest.c:9:5: note: 'ceil' is a builtin with type 'double (double)'
#       _configtest.c:10:5: warning: incompatible redeclaration of library function 'sqrt' [-Wincompatible-library-redeclaration]
#       int sqrt (void);
#           ^
#       _configtest.c:10:5: note: 'sqrt' is a builtin with type 'double (double)'
#       _configtest.c:11:5: warning: incompatible redeclaration of library function 'log10' [-Wincompatible-library-redeclaration]
#       int log10 (void);
#           ^
#       _configtest.c:11:5: note: 'log10' is a builtin with type 'double (double)'
#       _configtest.c:12:5: warning: incompatible redeclaration of library function 'log' [-Wincompatible-library-redeclaration]
#       int log (void);
#           ^
#       _configtest.c:12:5: note: 'log' is a builtin with type 'double (double)'
#       _configtest.c:13:5: warning: incompatible redeclaration of library function 'exp' [-Wincompatible-library-redeclaration]
#       int exp (void);
#           ^
#       _configtest.c:13:5: note: 'exp' is a builtin with type 'double (double)'
#       _configtest.c:14:5: warning: incompatible redeclaration of library function 'asin' [-Wincompatible-library-redeclaration]
#       int asin (void);
#           ^
#       _configtest.c:14:5: note: 'asin' is a builtin with type 'double (double)'
#       _configtest.c:15:5: warning: incompatible redeclaration of library function 'acos' [-Wincompatible-library-redeclaration]
#       int acos (void);
#           ^
#       _configtest.c:15:5: note: 'acos' is a builtin with type 'double (double)'
#       _configtest.c:16:5: warning: incompatible redeclaration of library function 'atan' [-Wincompatible-library-redeclaration]
#       int atan (void);
#           ^
#       _configtest.c:16:5: note: 'atan' is a builtin with type 'double (double)'
#       _configtest.c:17:5: warning: incompatible redeclaration of library function 'fmod' [-Wincompatible-library-redeclaration]
#       int fmod (void);
#           ^
#       _configtest.c:17:5: note: 'fmod' is a builtin with type 'double (double, double)'
#       _configtest.c:18:5: warning: incompatible redeclaration of library function 'modf' [-Wincompatible-library-redeclaration]
#       int modf (void);
#           ^
#       _configtest.c:18:5: note: 'modf' is a builtin with type 'double (double, double *)'
#       _configtest.c:19:5: warning: incompatible redeclaration of library function 'frexp' [-Wincompatible-library-redeclaration]
#       int frexp (void);
#           ^
#       _configtest.c:19:5: note: 'frexp' is a builtin with type 'double (double, int *)'
#       _configtest.c:20:5: warning: incompatible redeclaration of library function 'ldexp' [-Wincompatible-library-redeclaration]
#       int ldexp (void);
#           ^
#       _configtest.c:20:5: note: 'ldexp' is a builtin with type 'double (double, int)'
#       20 warnings generated.
#       clang _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
# ...
#   Building wheel for tzlocal (setup.py) ... done
#   Created wheel for tzlocal: filename=tzlocal-1.5.1-py3-none-any.whl size=17545 sha256=c3ecb1da3e8d50c14fdd3d5f840ca0acbdb7894c2f8d352a1a7eaf5753b896c8
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/7d/2a/d3/9b83608fd158b23f4d04b92572b93ab2d643faa2a3c46b6f34
# Successfully built gensim sklearn PyPDF2 autocorrect nltk EbookLib python-pptx tzlocal
# Failed to build numpy
# WARNING: Error parsing requirements for urllib3: [Errno 2] No such file or directory: '/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/urllib3-1.26.11.dist-info/METADATA'
# WARNING: Error parsing requirements for tzlocal: [Errno 2] No such file or directory: '/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/tzlocal-4.2.dist-info/METADATA'
# WARNING: Error parsing requirements for python-pptx: [Errno 2] No such file or directory: '/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/python_pptx-0.6.21.dist-info/METADATA'
# WARNING: Error parsing requirements for pdfminer-six: [Errno 2] No such file or directory: '/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/pdfminer.six-20191110.dist-info/METADATA'
# WARNING: Error parsing requirements for argcomplete: [Errno 2] No such file or directory: '/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/argcomplete-1.10.3.dist-info/METADATA'
# Installing collected packages: PyPDF2, pyahocorasick, contractions, autocorrect, argcomplete, urllib3, tzlocal, textsearch, python-pptx, pdfminer.six, numpy, nltk, inflect, idna, EbookLib, beautifulsoup4, scipy, requests, Flask, extract-msg, textract, gensim, sklearn
#   Attempting uninstall: argcomplete
#     WARNING: No metadata found in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages
#     Found existing installation: argcomplete 1.10.3
#     Can't uninstall 'argcomplete'. No files were found to uninstall.
#   Attempting uninstall: urllib3
#     WARNING: No metadata found in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages
#     Found existing installation: urllib3 1.26.11
#     Can't uninstall 'urllib3'. No files were found to uninstall.
#   Attempting uninstall: tzlocal
#     WARNING: No metadata found in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages
#     Found existing installation: tzlocal 4.2
#     Can't uninstall 'tzlocal'. No files were found to uninstall.
#   Attempting uninstall: python-pptx
#     WARNING: No metadata found in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages
#     Found existing installation: python-pptx 0.6.21
#     Can't uninstall 'python-pptx'. No files were found to uninstall.
#   Attempting uninstall: pdfminer.six
#     WARNING: No metadata found in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages
#     Found existing installation: pdfminer-six 20191110
#     Can't uninstall 'pdfminer-six'. No files were found to uninstall.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Running setup.py install for numpy ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for numpy did not run successfully.
#   │ exit code: 1
#   ╰─> [155 lines of output]
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#       /bin/sh: svnversion: command not found
#       non-existing path in 'numpy/distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/Users/shubhangi/opt/anaconda3/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/Users/shubhangi/opt/anaconda3/include']
#
#       non-existing path in 'numpy/random': 'src/splitmix64/splitmix.h'
#       /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:262: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize NAGFCompiler
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       Could not locate executable f77
#       customize IBMFCompiler
#       Could not locate executable xlf90
#       Could not locate executable xlf
#       customize IntelFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifc
#       customize GnuFCompiler
#       Could not locate executable g77
#       customize G95FCompiler
#       Could not locate executable g95
#       customize PGroupFCompiler
#       Could not locate executable pgfortran
#       don't know how to compile Fortran code on platform 'posix'
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       clang _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -c'
#       clang: _configtest.c
#       _configtest.c:1:5: warning: incompatible redeclaration of library function 'exp' [-Wincompatible-library-redeclaration]
#       int exp (void);
#           ^
#       _configtest.c:1:5: note: 'exp' is a builtin with type 'double (double)'
#       1 warning generated.
#       clang _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath' to include_dirs.
#       None - nothing done with h_files = ['build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/npy_math_internal.h']
#       building library "npysort" sources
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common' to include_dirs.
#       None - nothing done with h_files = ['build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_sort.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_partition.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/npy_binsearch.h']
#       building extension "numpy.core._dummy" sources
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/config.h' to sources.
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/_numpyconfig.h' to sources.
#       executing numpy/core/code_generators/generate_numpy_api.py
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/__multiarray_api.h' to sources.
#       numpy.core - nothing done with h_files = ['build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/config.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/__multiarray_api.h']
#       building extension "numpy.core._multiarray_tests" sources
#       building extension "numpy.core._multiarray_umath" sources
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/config.h' to sources.
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/_numpyconfig.h' to sources.
#       executing numpy/core/code_generators/generate_numpy_api.py
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/__multiarray_api.h' to sources.
#       executing numpy/core/code_generators/generate_ufunc_api.py
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/__ufunc_api.h' to sources.
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/umath' to include_dirs.
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath' to include_dirs.
#         adding 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common' to include_dirs.
#       numpy.core - nothing done with h_files = ['build/src.macosx-10.9-x86_64-3.9/numpy/core/src/umath/funcs.inc', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/umath/simd.inc', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/umath/loops.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/umath/matmul.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/umath/clip.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/npy_math_internal.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/src/common/templ_common.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/config.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/__multiarray_api.h', 'build/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy/__ufunc_api.h']
#       building extension "numpy.core._umath_tests" sources
#       building extension "numpy.core._rational_tests" sources
#       building extension "numpy.core._struct_ufunc_tests" sources
#       building extension "numpy.core._operand_flag_tests" sources
#       building extension "numpy.fft.pocketfft_internal" sources
#       building extension "numpy.linalg.lapack_lite" sources
#         adding 'numpy/linalg/lapack_lite/python_xerbla.c' to sources.
#       building extension "numpy.linalg._umath_linalg" sources
#         adding 'numpy/linalg/lapack_lite/python_xerbla.c' to sources.
#       building extension "numpy.random.entropy" sources
#       building extension "numpy.random.mt19937" sources
#       building extension "numpy.random.philox" sources
#       building extension "numpy.random.pcg64" sources
#       building extension "numpy.random.sfc64" sources
#       building extension "numpy.random.common" sources
#       building extension "numpy.random.bit_generator" sources
#       building extension "numpy.random.generator" sources
#       building extension "numpy.random.bounded_integers" sources
#       building extension "numpy.random.mtrand" sources
#       building data_files sources
#       build_src: building npy-pkg config files
#       running build_py
#       copying numpy/version.py -> build/lib.macosx-10.9-x86_64-cpython-39/numpy
#       copying build/src.macosx-10.9-x86_64-3.9/numpy/__config__.py -> build/lib.macosx-10.9-x86_64-cpython-39/numpy
#       copying build/src.macosx-10.9-x86_64-3.9/numpy/distutils/__config__.py -> build/lib.macosx-10.9-x86_64-cpython-39/numpy/distutils
#       running build_clib
#       customize UnixCCompiler
#       customize UnixCCompiler using build_clib
#       building 'npymath' library
#       compiling C sources
#       C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64 -I/Users/shubhangi/opt/anaconda3/include -fPIC -O2 -isystem /Users/shubhangi/opt/anaconda3/include -arch x86_64
#
#       compile options: '-Ibuild/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath -Inumpy/core/include -Ibuild/src.macosx-10.9-x86_64-3.9/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/shubhangi/opt/anaconda3/include/python3.9 -Ibuild/src.macosx-10.9-x86_64-3.9/numpy/core/src/common -Ibuild/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath -Ibuild/src.macosx-10.9-x86_64-3.9/numpy/core/src/common -Ibuild/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath -c'
#       llvm-ar: adding 4 object files to build/temp.macosx-10.9-x86_64-cpython-39/libnpymath.a
#       error: Command "/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_aafi60xe3m/croots/recipe/python-split_1661469468466/_build_env/bin/llvm-ar rcs build/temp.macosx-10.9-x86_64-cpython-39/libnpymath.a build/temp.macosx-10.9-x86_64-cpython-39/numpy/core/src/npymath/npy_math.o build/temp.macosx-10.9-x86_64-cpython-39/build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/ieee754.o build/temp.macosx-10.9-x86_64-cpython-39/build/src.macosx-10.9-x86_64-3.9/numpy/core/src/npymath/npy_math_complex.o build/temp.macosx-10.9-x86_64-cpython-39/numpy/core/src/npymath/halffloat.o" failed with exit status 127
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Rolling back uninstall of numpy
#   Moving to /Users/shubhangi/opt/anaconda3/bin/f2py
#    from /private/var/folders/mq/t1w0x9bs7012b_gncdw4zfzc0000gn/T/pip-uninstall-x_vuxod3/f2py
#   Moving to /Users/shubhangi/opt/anaconda3/bin/f2py3
#    from /private/var/folders/mq/t1w0x9bs7012b_gncdw4zfzc0000gn/T/pip-uninstall-x_vuxod3/f2py3
#   Moving to /Users/shubhangi/opt/anaconda3/bin/f2py3.9
#    from /private/var/folders/mq/t1w0x9bs7012b_gncdw4zfzc0000gn/T/pip-uninstall-x_vuxod3/f2py3.9
#   Moving to /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/numpy-1.21.5.dist-info/
#    from /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/~umpy-1.21.5.dist-info
#   Moving to /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/numpy/
#    from /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/~umpy
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install textract
# Out:
# Requirement already satisfied: textract in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (1.6.5)
# Requirement already satisfied: SpeechRecognition~=3.8.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (3.8.1)
# Requirement already satisfied: docx2txt~=0.8 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (0.8)
# Requirement already satisfied: extract-msg<=0.29.* in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (0.28.7)
# Requirement already satisfied: chardet==3.* in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (3.0.4)
# Requirement already satisfied: six~=1.12.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (1.12.0)
# Requirement already satisfied: xlrd~=1.2.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (1.2.0)
# Requirement already satisfied: beautifulsoup4~=4.8.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (4.8.2)
# Requirement already satisfied: python-pptx~=0.6.18 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (0.6.18)
# Collecting pdfminer.six==20191110
#   Using cached pdfminer.six-20191110-py2.py3-none-any.whl (5.6 MB)
# Requirement already satisfied: argcomplete~=1.10.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textract) (1.10.0)
# Requirement already satisfied: pycryptodome in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six==20191110->textract) (3.15.0)
# Requirement already satisfied: sortedcontainers in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4~=4.8.0->textract) (2.3.1)
# Requirement already satisfied: olefile>=0.46 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from extract-msg<=0.29.*->textract) (0.46)
# Requirement already satisfied: compressed-rtf>=1.0.6 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from extract-msg<=0.29.*->textract) (1.0.6)
# Requirement already satisfied: imapclient==2.1.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from extract-msg<=0.29.*->textract) (2.1.0)
# Collecting tzlocal>=2.1
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: ebcdic>=1.1.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from extract-msg<=0.29.*->textract) (1.1.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from python-pptx~=0.6.18->textract) (3.0.3)
# Requirement already satisfied: Pillow>=3.3.2 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from python-pptx~=0.6.18->textract) (9.2.0)
# Requirement already satisfied: lxml>=3.1.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from python-pptx~=0.6.18->textract) (4.9.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from tzlocal>=2.1->extract-msg<=0.29.*->textract) (0.1.0.post0)
# Requirement already satisfied: tzdata in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=2.1->extract-msg<=0.29.*->textract) (2022.6)
# Installing collected packages: pdfminer.six, tzlocal
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20181108
#     Uninstalling pdfminer.six-20181108:
#       Successfully uninstalled pdfminer.six-20181108
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 1.5.1
#     Uninstalling tzlocal-1.5.1:
#       Successfully uninstalled tzlocal-1.5.1
# Successfully installed pdfminer.six-20191110 tzlocal-4.2

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.25.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)

# %%
# !pip install Flask
# Out:
# Requirement already satisfied: Flask in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: click>=5.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask) (2.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask) (2.0.1)

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.21.5)
# Requirement already satisfied: scipy>=0.18.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.9.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim) (5.2.1)

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=1bc88c2214eba623c8c16cfb48d71fcfb6b333505f4b68bcee8ca73fbe4b20c0
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1

# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (1.26.0)

# %%
# !pip install autocorrect
# Out:
# Requirement already satisfied: autocorrect in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (0.4.4)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: tqdm in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from nltk) (2022.7.9)

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (0.0.21)

# %%
# !pip install textsearch
# Out:
# Requirement already satisfied: textsearch in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (0.0.17)
# Requirement already satisfied: pyahocorasick in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textsearch) (1.4.4)
# Requirement already satisfied: Unidecode in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from textsearch) (1.2.0)

# %%
# !pip install inflect
# Out:
# Collecting inflect
#   Downloading inflect-6.0.2-py3-none-any.whl (34 kB)
# Collecting pydantic>=1.9.1
#   Downloading pydantic-1.10.2-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.9.1->inflect) (4.3.0)
# Installing collected packages: pydantic, inflect
# Successfully installed inflect-6.0.2 pydantic-1.10.2

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (1.21.5)

# %%
# !pip install pdfminer.six
# Out:
# Requirement already satisfied: pdfminer.six in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (20191110)
# Requirement already satisfied: sortedcontainers in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six) (2.4.0)
# Requirement already satisfied: pycryptodome in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six) (3.15.0)
# Requirement already satisfied: six in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six) (1.12.0)
# Requirement already satisfied: chardet in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six) (3.0.4)

# %%
# %run app.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Desktop/text/app.py in <module>
#      49 from flask import (Flask,session, g, json, Blueprint,flash, jsonify, redirect, render_template, request,
#      50                    url_for, send_from_directory)
# ---> 51 from gensim.summarization import summarize
#      52 from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
#      53 from sklearn.neighbors import NearestNeighbors
#
# ModuleNotFoundError: No module named 'gensim.summarization'

# %%
# !pip install gensim.summarization
# Out:
# ERROR: Could not find a version that satisfies the requirement gensim.summarization (from versions: none)
# ERROR: No matching distribution found for gensim.summarization

# %%
# !pip install genism==3.8.3
# Out:
# ERROR: Could not find a version that satisfies the requirement genism==3.8.3 (from versions: none)
# ERROR: No matching distribution found for genism==3.8.3

# %%
genism --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mq/t1w0x9bs7012b_gncdw4zfzc0000gn/T/ipykernel_20643/776276049.py in <module>
# ----> 1 genism --version
#
# NameError: name 'genism' is not defined

# %%
# !pip install genism
# Out:
# ERROR: Could not find a version that satisfies the requirement genism (from versions: none)
# ERROR: No matching distribution found for genism

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (4.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.21.5)
# Requirement already satisfied: scipy>=0.18.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.9.1)

# %%
# !pip install gensim==3.8.3
# Out:
# Collecting gensim==3.8.3
#   Downloading gensim-3.8.3.tar.gz (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 1.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.3 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim==3.8.3) (1.21.5)
# Requirement already satisfied: scipy>=0.18.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim==3.8.3) (1.9.1)
# Requirement already satisfied: six>=1.5.0 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim==3.8.3) (1.12.0)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from gensim==3.8.3) (5.2.1)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.8.3-cp39-cp39-macosx_10_9_x86_64.whl size=24173427 sha256=69867e2c11b74b0615d724dcdc6459fd2bdb80e44b4b4de0a0d3748f510029a9
#   Stored in directory: /Users/shubhangi/Library/Caches/pip/wheels/ca/5d/af/618594ec2f28608c1d6ee7d2b7e95a3e9b06551e3b80a491d6
# Successfully built gensim
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.1.2
#     Uninstalling gensim-4.1.2:
#       Successfully uninstalled gensim-4.1.2
# Successfully installed gensim-3.8.3

# %%
# %run app.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/Desktop/text/app.py in <module>
#      52 from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
#      53 from sklearn.neighbors import NearestNeighbors
# ---> 54 from werkzeug import secure_filename
#      55
#      56 import pdf2txt as pdf
#
# ImportError: cannot import name 'secure_filename' from 'werkzeug' (/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/werkzeug/__init__.py)

# %%
# !pip install werkzeug==0.16.0
# Out:
# Collecting werkzeug==0.16.0
#   Downloading Werkzeug-0.16.0-py2.py3-none-any.whl (327 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.3/327.3 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: werkzeug
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
# Successfully installed werkzeug-0.16.0

# %%
# %run app.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/Desktop/text/app.py in <module>
#      52 from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
#      53 from sklearn.neighbors import NearestNeighbors
# ---> 54 from werkzeug import secure_filename
#      55
#      56 import pdf2txt as pdf
#
# ImportError: cannot import name 'secure_filename' from 'werkzeug' (/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/werkzeug/__init__.py)

# %%
# !pip install Flask-Reuploaded
# Out:
# Collecting Flask-Reuploaded
#   Downloading Flask_Reuploaded-1.2.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: Flask>=1.0.4 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask-Reuploaded) (1.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->Flask-Reuploaded) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->Flask-Reuploaded) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->Flask-Reuploaded) (0.16.0)
# Requirement already satisfied: click>=5.1 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->Flask-Reuploaded) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->Flask-Reuploaded) (2.0.1)
# Installing collected packages: Flask-Reuploaded
# Successfully installed Flask-Reuploaded-1.2.0

# %%
# %run app.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/Desktop/text/app.py in <module>
#      57 import PyPDF2
#      58
# ---> 59 import screen
#      60 import search
#      61 import hashlib
#
# ~/Desktop/text/screen.py in <module>
#       9 from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
#      10 from sklearn.neighbors import NearestNeighbors
# ---> 11 from werkzeug import secure_filename
#      12
#      13 import pdf2txt as pdf
#
# ImportError: cannot import name 'secure_filename' from 'werkzeug' (/Users/shubhangi/opt/anaconda3/lib/python3.9/site-packages/werkzeug/__init__.py)

# %%
# !pip install werkzeug==2.1.2
# Out:
# Collecting werkzeug==2.1.2
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 958.4 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: werkzeug
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 0.16.0
#     Uninstalling Werkzeug-0.16.0:
#       Successfully uninstalled Werkzeug-0.16.0
# Successfully installed werkzeug-2.1.2

# %%
# %run app.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Desktop/text/app.py in <module>
#     166
#     167 if __name__ == "__main__":
# --> 168     from waitress import serve
#     169     serve(app, host="0.0.0.0", port=8080)
#     170
#
# ModuleNotFoundError: No module named 'waitress'

# %%
# !pip install waitress
# Out:
# Collecting waitress
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 498.1 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: waitress
# Successfully installed waitress-2.1.2

# %%
# %run app.py

# %%
export FLASK_APP=app.py

# %%
export FLASK_ENV=development

# %%
flask run

# %%
# %run app.py

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/shubhangi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True
